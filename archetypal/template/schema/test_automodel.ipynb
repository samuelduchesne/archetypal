# %%
from automodel import UmiTemplateLibrary

with open("lib.json",'r') as f:
    data = f.read()

print(UmiTemplateLibrary.model_validate_json(data).model_dump_json(indent=4))
# Out:
# {
#     "id": "ae42b5e3-505f-46d3-809a-adb176eb76fe",
#     "Templates": {
#         "id": "b28d2d11-005e-4e67-be69-2147dccab1d8",
#         "objects": [
#             {
#                 "id": "cd69afa7-e470-43a6-ad02-b3342d26ea51",
#                 "Perimeter": {
#                     "id": "9043cbf0-3f82-44e9-9394-7fffcbc2ad80",
#                     "DaylightWorkplaneHeight": 1.0,
#                     "Constructions": {
#                         "id": "b8702e3b-3c8e-4385-b81e-e26f1470b803",
#                         "Partition": {
#                             "id": "76479242-04c2-4927-950e-a4fbd88fb5bf",
#                             "Layers": {
#                                 "id": "8150fb27-2c4d-4818-8c52-8419e86a1b83",
#                                 "objects": [
#                                     {
#                                         "id": "da6c0b67-9e5b-4fea-9c58-8355a608faf8",
#                                         "Thickness": 0.1,
# ...
